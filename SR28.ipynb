# %%
# Out:
#       NDB_No                   Shrt_Desc  Water_(g)  Energ_Kcal  Protein_(g)  \
# 0       1001            BUTTER,WITH SALT      15.87         717         0.85
# 1       1002      BUTTER,WHIPPED,W/ SALT      16.72         718         0.49
# 2       1003        BUTTER OIL,ANHYDROUS       0.24         876         0.28
# 3       1004                 CHEESE,BLUE      42.41         353        21.40
# 4       1005                CHEESE,BRICK      41.11         371        23.24
# ...      ...                         ...        ...         ...          ...
# 8785   83110             MACKEREL,SALTED      43.00         305        18.50
# 8786   90240  SCALLOP,(BAY&SEA),CKD,STMD      70.25         111        20.54
# 8787   90480                  SYRUP,CANE      26.00         269         0.00
# 8788   90560                   SNAIL,RAW      79.20          90        16.10
# 8789   93600            TURTLE,GREEN,RAW      78.50          89        19.80
#
# ...

# %%
sr_28[["Shrt_Desc", "GmWt_1", "GmWt_Desc1", "GmWt_2", "GmWt_Desc2"]]
# Out:
#                        Shrt_Desc  GmWt_1                          GmWt_Desc1  \
# 0               BUTTER,WITH SALT    5.00          1 pat,  (1" sq, 1/3" high)
# 1         BUTTER,WHIPPED,W/ SALT    3.80          1 pat,  (1" sq, 1/3" high)
# 2           BUTTER OIL,ANHYDROUS   12.80                              1 tbsp
# 3                    CHEESE,BLUE   28.35                                1 oz
# 4                   CHEESE,BRICK  132.00                        1 cup, diced
# ...                          ...     ...                                 ...
# 8785             MACKEREL,SALTED   80.00  1 piece,  (5-1/2" x 1-1/2" x 1/2")
# 8786  SCALLOP,(BAY&SEA),CKD,STMD   85.00                                3 oz
# 8787                  SYRUP,CANE   21.00                           1 serving
# 8788                   SNAIL,RAW   85.00                                3 oz
# 8789            TURTLE,GREEN,RAW   85.00                                3 oz
#
#       GmWt_2              GmWt_Desc2
# ...
